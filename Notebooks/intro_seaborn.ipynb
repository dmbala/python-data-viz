# %% [markdown]
# <a href="https://colab.research.google.com/github/dmbala/python-data-viz/blob/main/Notebooks/intro_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Intro to Seaborn
#
# * Based on matplotlib.
# * Provides a stastical overview of data.
# * Good visualization of data
#
# ### Topics
# * Matplotlib and Seaborn
# * Bar and Count Plots
# * Box Plot
# * Violin Plot
# * Joint Plot
# * Pair Plot
#
# ![alt text](https://github.com/dmbala/python-data-viz/blob/main/Figs/ggplot.png?raw=true)

# %% [markdown]
# ## Import packages and data

# %%
# importing packages 
import seaborn as sns 
import matplotlib.pyplot as plt 
  
# loading dataset 
df = sns.load_dataset("iris")

# %% [markdown]
# ![alt text](https://github.com/dmbala/python-data-viz/blob/main/Figs/iris-machinelearning.png?raw=true)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## A simple Seaborn Plot
# * Nice plot with one-line code
# * Does the stastics such as confidence interval here
# * Integrates well with matplotlib

# %%
# draw lineplot 
sns.lineplot(x="sepal_length", y="sepal_width", data=df)
#sns.lineplot(x="sepal_length", y="sepal_width", data=df, ci=None)
# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')
# Out:
# Text(0.5, 1.0, 'Title using Matplotlib Function')

# %% [markdown]
# * Customize the background and style
# * Utilize subplots from matplotlib

# %%
# setting the color palette
sns.set_palette('vlag')
# Set the theme to dark
sns.set_style("white")
plt.subplot(211)
sns.lineplot(x="sepal_length", y="sepal_width", data=df)
  
# setting another color palette
sns.set_palette('Accent')
# Set the theme to dark
sns.set_style("dark")
plt.subplot(212)
sns.lineplot(x="sepal_length", y="sepal_width", data=df)

# %% [markdown]
# Count and display the categorical variables - Useful for checking data balance

# %%
# count plot on single categorical variable
sns.countplot(x ='species', data = df)

# %% [markdown]
# Vertical and Horizontal Bar Plots

# %%
sns.barplot(x ='species', y='sepal_length', data = df)

# %%
sns.barplot(y ='species', x='sepal_length', data = df)

# %%
plt.subplot(1,2,1)
sns.barplot(x ='species', y='sepal_length', data = df)
plt.subplot(1,2,2)
sns.barplot(y ='species', x='sepal_length', data = df)
# set the spacing between subplots
plt.subplots_adjust(left=0.1, bottom=0.1, right=1.2, top=0.9, wspace=0.5, hspace=0.4)
plt.show()

# %% [markdown]
# ### Box Plot
# ![alt text](https://github.com/dmbala/python-data-viz/blob/main/Figs/boxplot_tds.png?raw=true)

# %%
sns.boxplot(x ='species', y = 'sepal_width',  data = df)

# %% [markdown]
# ### Box, Violin, Strip, and Swarm Plots

# %%
plt.subplot(2,2,1)
sns.boxplot(x ='species', y = 'sepal_width',  data = df)
plt.subplot(2,2,2)
sns.violinplot(x ='species', y = 'sepal_width',  data = df)
plt.subplot(2,2,3)
sns.stripplot(x ='species', y = 'sepal_width',  data = df)
plt.subplot(2,2,4)
sns.swarmplot(x ='species', y = 'sepal_width',  data = df)
plt.subplots_adjust(left=0.1, bottom=0.1, right=1.2, top=0.9, wspace=0.5, hspace=0.4)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Histogram and Grouped Histogram

# %%
plt.subplot(1,2,1)
sns.histplot(x ='sepal_length', data = df, kde='True')
plt.subplot(1,2,2)
sns.histplot(x ='sepal_length', data = df, hue='species', kde='True')
plt.subplots_adjust(left=0.1, bottom=0.1, right=1.5, top=0.9, wspace=0.4, hspace=0.1)
plt.show()

# %% [markdown]
# ### Contour and Jointplot

# %%
sns.kdeplot(df.sepal_length, df.sepal_width)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(df.sepal_length, df.sepal_width, kind="kde", size=7)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Correlation Among Variables

# %%
plt.figure(figsize=(7,4))
sns.heatmap(df.corr(),annot=True,cmap='winter')

# %% [markdown]
# Histogram of Variables

# %%
sns.histplot(df)

# %%
#df.hist(edgecolor='black', linewidth=1.2)
#fig=plt.gcf()
#fig.set_size_inches(12,6)
#plt.show()

# %% [markdown]
# ## Seaborn Pairgrid and Pairplot
# Pairgrid: Grid of small subplots. After pairgrid, use the pairgrid.map function to draw the plots.
#
# Pairplot: Quick way to plot on the grid.

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(df) # default: scatter plots for the off-diagonal and histogram distribution for the diagonal

# %% [markdown]
# **Pairplot - group by the species"

# %%
sns.pairplot(df, hue='species') # adding hue changes the diagonal to kde

# %%
sns.pairplot(df, hue='species', corner='True')

# %% [markdown]
# Histogram + KDE + Resolve by Type

# %%
plt.style.use('classic')
g = sns.PairGrid(df, hue="species")
g.map_diag(sns.histplot, kde="True")
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %% [markdown]
# ## FacetGrid - Looking at the subset of the data

# %%
g = sns.FacetGrid(df, col="species", hue="species")
g.map(sns.scatterplot, "sepal_length", "sepal_width")
g.add_legend()

# %%
g = sns.FacetGrid(df, col="petal_width", hue="species")
g.map(sns.scatterplot, "sepal_length", "sepal_width")
g.add_legend()

# %% [markdown]
# References and Further Reading
# * https://seaborn.pydata.org/tutorial.html
# * https://www.kaggle.com/code/kanncaa1/seaborn-tutorial-for-beginners/notebook
# * https://www.geeksforgeeks.org/python-seaborn-tutorial/
# * https://www.geeksforgeeks.org/data-visualization-with-python/
# * https://www.kaggle.com/code/rakesh6184/seaborn-plot-to-visualize-iris-data/data
# * https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
# * https://www.science-craft.com/2014/07/08/introducing-the-grammar-of-graphics-plotting-concept/
# * https://github.com/dmbala/python-data-viz
