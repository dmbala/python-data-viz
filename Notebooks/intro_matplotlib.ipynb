# %% [markdown]
# # Matplotlib

# %% [markdown]
# * The first release in 2002,created by John Hunter (1968-2012)
# * Most widely used plotting library in Python
# * Save figures in pdf, png, jpg, etc.
# * Data Structure - input data needs to be in numpy array

# %% [markdown]
# **Settings**
# For additional reference scripts and notebooks check the repo: https://github.com/dmbala/python-data-viz
#
# Binder Hub: https://mybinder.org/v2/gh/dmbala/binder-PyML/main

# %% [markdown]
# ## Numpy

# %% [markdown]
# Numpy arrays (or ndarray objects) are compact and homogenous data types. Several numberical and graphical libraries utilize numpy.

# %%
# Adding two lists
a = [1, 2, 3]
b = [1, 1, 1]
print (a + b)
# Out:
# [1, 2, 3, 1, 1, 1]

# %% [markdown]
# **Adding two NumPy arrays**

# %%
import numpy as np
arr_a = np.array([1,2,3])
arr_b = np.array([1,1,1])
print(arr_a + arr_b)
# Out:
# [2 3 4]

# %% [markdown]
# ## Pandas

# %% [markdown]
# * pandas series - one dimentaion array that can hold any data type
# * pandas dataframe - two dimensional labeled data structure that can hold columns of any data type. The data in a column is homogenous data type.

# %% [markdown]
# #### Pandas Series

# %%
import pandas as pd
S1 = pd.Series([1, 2, 3, 4, 5])
S2 = pd.Series([1, 2, 3, 4, 5])
S3 = S1 + S2 # Vector operations work
print(S3)
print(S3.index) 
print(S3.values)
print("S[2]= ", S3[2]) # Access by Index
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64
# RangeIndex(start=0, stop=5, step=1)
# [ 2  4  6  8 10]
# S[2]=  6

# %%
fruits1 = ['apples', 'oranges', 'cherries', 'pears']
fruits2 = ['peaches', 'oranges', 'cherries', 'apples']

S1 = pd.Series([1, 2, 3, 4], index=fruits1) # Labels for the index
S2 = pd.Series([4, 2, 3, 1], index=fruits2) 
print(S1)
print(S2)
print("S1[apples]=", S1['apples']) # Access by labeled index
print("S1.iloc[0]", S1.iloc[0])
# Out:
# apples      1
# oranges     2
# cherries    3
# pears       4
# dtype: int64
# peaches     4
# oranges     2
# cherries    3
# apples      1
# dtype: int64
# S1[apples]= 1
# S1.iloc[0] 1

# %%
S3 = S1 + S2
print(S3) # Vector operations are based on the labeled index
# Out:
# apples      2.0
# cherries    6.0
# oranges     4.0
# peaches     NaN
# pears       NaN
# dtype: float64

# %%
print(S3.dropna())
# Out:
# apples      2.0
# cherries    6.0
# oranges     4.0
# dtype: float64

# %% [markdown]
# #### Pandas Dataframe

# %%
data = [['Axel',32], ['Alice', 26], ['Alex', 45]]
df = pd.DataFrame(data,columns=['Name','Age'])
print(df)
# Out:
#     Name  Age
# 0   Axel   32
# 1  Alice   26
# 2   Alex   45

# %%
print(df['Name']) # Accessing the column by label
print("Second Entry of Column labeled as Name = ", df['Name'][1]) # Accessing specific element
print("Row 1 =", df.loc[1]) # Accessing specific row
# Out:
# 0     Axel
# 1    Alice
# 2     Alex
# Name: Name, dtype: object
# Second Entry of Column labeled as Name =  Alice
# Row 1 = Name    Alice
# Age        26
# Name: 1, dtype: object

# %%
new_col = pd.DataFrame(["football","soccer","base ball"], columns=['game'])
df['sports'] = new_col['game']
print(df)
print(new_col)
# Out:
#     Name  Age     sports
# 0   Axel   32   football
# 1  Alice   26     soccer
# 2   Alex   45  base ball
#         game
# 0   football
# 1     soccer
# 2  base ball

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# ![alt text](https://github.com/dmbala/python-data-viz/blob/main/Figs/fig_ax_anatomy.png?raw=true)

# %% [markdown]
# ![alt text](https://github.com/dmbala/python-data-viz/blob/main/Figs/anatomy_fig_ax.png?raw=true)

# %% [markdown]
# ### Import libraries

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **A simple example**

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = 2 + 3.0*x**2.0

plt.plot(x, y)

# %% [markdown]
# **Feeding a Python list won't work**

# %%
x = [0, 1, 2, 3, 4, 5]
y = 2 + x

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-008799611bc6> in <module>()
#       1
#       2 x = [0, 1, 2, 3, 4, 5]
# ----> 3 y = 2 + x
#       4
#       5 plt.plot(x, y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %% [markdown]
# **Chnage figure size**

# %%
x = np.arange(-20., 20., 0.5)
y = np.sin(x)/x
plt.figure(figsize=(3, 3)) # set display size in inches by passing argument to figure instance
plt.plot(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Saving figure to an image file

# %%
x = np.arange(-20., 20., 0.1)
y = np.sin(x)/x


plt.plot(x, y)
plt.savefig("st_line.png") # savefig instance

# %% [markdown]
# ## Parts of a Figure

# %% [markdown]
# ## Object Oriented vs Pyplot/Functional Interface
# * OO Interface offers fine grained control
# * Pyplot offers a familiar to MATLAB and easy interface

# %% [markdown]
# **OO Interface**

# %%
fig = plt.figure()  # an empty figure with no Axes

# %%
fig, ax = plt.subplots()  # a figure with a single Axes

# %%
x = np.arange(-20., 20., 0.1)
y = np.sin(x)/x

fig, ax = plt.subplots() # Creates instances - fig, ax
ax.plot(x,y) # change the ax instance
ax.set_title("Oscillating function")
plt.show()

# %% [markdown]
# **PyPlot/Functional Interface**

# %%
x = np.arange(-20., 20., 0.1)
y = np.sin(x)/x

plt.plot(x,y) #Pyplot Interface
plt.title("Oscillating Function")
# Out:
# Text(0.5, 1.0, 'Oscillating Function')

# %% [markdown]
# Multiple Curves

# %%
x = np.arange(-20., 20., 0.1)
y1 = np.sin(x)/x
y2 = np.sin(2.0*x)/x
plt.plot(x, y1)
plt.plot(x, y2)

# %% [markdown]
# Addition properties to the figures: colors, symbols, and legends

# %%
x = np.arange(-20., 20., 0.1)
y1 = np.sin(x)/x
y2 = np.sin(2.0*x)/x

plt.plot(x,y1, 'r-v',x,y2, 'b-o') # red-triangle, blue-dot
plt.legend(["slow oscillation", "fast oscillation"]) #Legends

# %% [markdown]
# Annotate the plot and curves - Title, labels, legends, colors, symbol, lines, ...

# %%
x = np.arange(-20., 20., 0.1)
y1 = np.sin(x)/x
y2 = np.sin(2.0*x)/x

plt.plot(x,y1, 'r-v',x,y2, 'b-o')                    # red-triangle, blue-dot
plt.legend(["slow oscillation", "fast oscillation"]) #Legends

plt.title ("Oscilating function", fontsize=22)
plt.xlabel('radians', fontsize=18)               # x label
plt.ylabel('amplitude', fontsize=18)             # y label
plt.axhline(y=0, color='k')
plt.yticks(fontsize=16)
plt.grid(False)

# %% [markdown]
# ### Scatter Plots

# %%
x = np.random.rand(1000)
y = np.exp(-10*x)
plt.plot(x, y)

# %%
x = np.random.rand(1000)
y = np.exp(-10*x)
plt.scatter(x, y)

# %%
npoints = 50
x = 20*np.random.rand(npoints)
y = x*np.sin(x)
size = 1000.0*np.random.rand(npoints) # array of values defining size for the points
color_val = np.random.rand(npoints) # array of color values
plt.figure(figsize=(14, 4))
plt.scatter(x,y,size,color_val) 
plt.colorbar() #Adds the side colorbar

# %% [markdown]
# ### Bar Charts
# * Preferred over Pie Charts

# %%
x = np.arange(0.2, 1., 0.1)
y = x**2.0
plt.bar(x,y, 0.05, color='green')
# Out:
# <BarContainer object of 8 artists>

# %%
x = np.arange(0.2, 1., 0.1)
y = x**2.0
plt.barh(x,y, 0.05, color='green')
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# ### Grouped Bar Charts

# %%
last_week = [22, 35, 30, 34, 27, 30]
this_week = [25, 31, 36, 24, 25, 33]
names = ['Mary', 'Larry', 'Tory', 'Barry', 'Bill', 'Will']


width = 0.25   
ticks = np.arange(len(names)) 
#print(ticks, ticks + width, ticks + width/2)   
plt.bar(ticks, last_week, width, label='Last week')
plt.bar(ticks + width, this_week, width, align="center", label='This week')
plt.xticks(ticks + width/2,names, fontsize=20, rotation=45) # Adjust xtics to the center and rotate by 45 degrees
plt.legend(["Last Week", "Current Week"])
plt.ylabel("Number of Points", fontsize=20)
plt.show()
# Out:
# [0 1 2 3 4 5] [0.25 1.25 2.25 3.25 4.25 5.25] [0.125 1.125 2.125 3.125 4.125 5.125]

# %% [markdown]
# ### Stacked Bar Charts
#
# Displays the highest value of one with respect to the other bar

# %%
last_week = [22, 35, 30, 34, 27, 30]
this_week = [18, 31, 33, 24, 25, 33]
names = ['Mary', 'Larry', 'Tory', 'Barry', 'Bill', 'Will']


width = 0.25   
ticks = np.arange(len(names))    
plt.bar(ticks, last_week, width, label='Last week')
plt.bar(ticks, this_week, width, align="center", label='This week')
plt.xticks(ticks,names, fontsize=20, rotation=45)
plt.legend(["Last Week", "Current Week"])
plt.ylabel("Number of Points", fontsize=20)
plt.show()

# %% [markdown]
# ### Pie Charts

# %%
last_week = [22, 35, 30, 34, 27, 30]
this_week = [18, 31, 33, 24, 25, 33]
names = ['Mary', 'Larry', 'Tory', 'Barry', 'Bill', 'Will']


width = 0.25   
ticks = np.arange(len(names))    
plt.pie(last_week, labels=names)
plt.show()

# %% [markdown]
# ## Subplots - Multiple plots in one figure

# %% [markdown]
# One row and two columns - Functional Approach

# %%
plt.subplot(1,2,1)
plt.text(0.5,0.5,"LEFT", ha='center', fontsize='20', color='green')
plt.subplot(1,2,2)
plt.text(0.5,0.5,"RIGHT", ha='center', fontsize='20', color='blue')
# Out:
# Text(0.5, 0.5, 'RIGHT')

# %% [markdown]
# One row and two columns - Object Approach

# %%
fig, (ax1, ax2)  = plt.subplots(1, 2) 
ax1.text( 0.5, 0.5, "LEFT", color="red", fontsize=20, ha='center')
ax2.text( 0.5, 0.5, "RIGHT", color="blue", fontsize=20, ha='center')
plt.show()

# %% [markdown]
# Two rows and one column - Functional Approach

# %%
plt.subplot(2,1,1)
plt.text(0.5,0.5,"TOP", ha='center', fontsize='20', color='green')
plt.subplot(2,1,2)
plt.text(0.5,0.5,"BOTTOM", ha='center', fontsize='20', color='blue')
# Out:
# Text(0.5, 0.5, 'BOTTOM')

# %% [markdown]
# Two rows and one column - Object Approach

# %%
fig, (ax1, ax2)  = plt.subplots(2, 1) 
ax1.text( 0.5, 0.5, "TOP", color="red", fontsize=20, ha='center')
ax2.text( 0.5, 0.5, "BOTTOM", color="blue", fontsize=20, ha='center')
plt.show()

# %% [markdown]
# Matrix of Plots - Object Approach

# %%
rows, cols = 2, 4
fig, ax = plt.subplots(rows, cols, sharex='col', sharey='row')
                    
for row in range(rows):
    for col in range(cols):
        ax[row, col].text(0.5, 0.5, str((row,col)),fontsize=22,ha='center')
                      
plt.show()

# %% [markdown]
# Matrix of Plots - Functional approach Approach

# %%
fig_index = 1            
for row in range(0, rows):
    for col in range(0, cols):
         plt.subplot(rows,cols,fig_index)
        
         plt.text(0.5,0.5, str((row,col,fig_index)), ha='center', fontsize='16', color='green')   
         if row == 2: 
             plt.xticks([])
         if col > 0:
             plt.yticks([])      
         fig_index = fig_index + 1            
plt.show()

# %%
x = np.random.normal(0, 1, 1000)
y = x**2.0

plt.subplot(1,2,1) # 1x2 plots
plt.scatter(x,y)
plt.subplot(1,2,2)
plt.hist(x)
# Out:
# (array([  1.,   5.,  36., 119., 212., 275., 199., 105.,  38.,  10.]),
#  array([-3.61165008, -2.94974675, -2.28784342, -1.62594009, -0.96403675,
#         -0.30213342,  0.35976991,  1.02167324,  1.68357657,  2.3454799 ,
#          3.00738323]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Changing the face color of the subplots

# %%
x = np.random.normal(0, 1, 1000)
y = x**2.0

plt.subplot(2,1,1, fc='y')
plt.scatter(x,y)
plt.subplot(2,1,2, fc='g')
plt.hist(x)
# Out:
# (array([  8.,  21.,  57., 152., 226., 233., 163.,  98.,  37.,   5.]),
#  array([-3.14006833, -2.53734588, -1.93462343, -1.33190098, -0.72917852,
#         -0.12645607,  0.47626638,  1.07898884,  1.68171129,  2.28443374,
#          2.88715619]),
#  <a list of 10 Patch objects>)

# %%
x = np.arange(-20., 20., 0.1)
y = np.sin(x)/x 
dy_dx = np.cos(x)/x -np.sin(x)/x**2.0

plt.subplot(2,1,1)
plt.plot(x, y)
plt.xticks([])

plt.subplot(2,1,2)
plt.plot(x, dy_dx)

# %% [markdown]
# ### Subplots can be of different types - scaterplot, bar, etc.

# %%
x = np.random.normal(0, 1, 1000)
y = x**2.0
y1 = x**3.0

plt.subplot(2,2,1)
plt.scatter(x,y)

plt.subplot(2,2,2)
plt.hist(y, color='black')

plt.subplot(2,2,3)
plt.scatter(x,y1, color='green')

plt.subplot(2,2,4)
plt.hist(y1, color='red')
# Out:
# (array([  1.,   6.,   9.,  55., 872.,  42.,  13.,   0.,   1.,   1.]),
#  array([-28.83205586, -22.41889406, -16.00573225,  -9.59257045,
#          -3.17940865,   3.23375315,   9.64691496,  16.06007676,
#          22.47323856,  28.88640036,  35.29956217]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Each subplot can be independtly adjusted

# %%
x = np.random.normal(0, 1, 1000)
y = x**2.0
y1 = x**3.0

plt.subplot(2,2,1)
plt.scatter(x,y)
plt.xticks([])  # Removes the xticks

plt.subplot(2,2,2)
plt.hist(y, color='black')
# fine grained control on ticks
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off

plt.subplot(2,2,3)
plt.scatter(x,y1, color='green')

plt.subplot(2,2,4)
plt.hist(y1, color='red')
# Out:
# (array([  3.,   6.,  29., 879.,  67.,  11.,   3.,   1.,   0.,   1.]),
#  array([-28.32512155, -20.49865682, -12.67219209,  -4.84572737,
#           2.98073736,  10.80720208,  18.63366681,  26.46013153,
#          34.28659626,  42.11306098,  49.93952571]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Dealing with more dimensions - Controus and 3D plots

# %% [markdown]
# ### Contour Plots

# %%
fig = plt.figure(figsize=(6,5))
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax = fig.add_axes([left, bottom, width, height]) 

start, stop, n_values = -8, 8, 800

x_vals = np.linspace(start, stop, n_values)
y_vals = np.linspace(start, stop, n_values)
X, Y = np.meshgrid(x_vals, y_vals)


Z = np.sqrt(X**2 + Y**2)

cp = plt.contourf(X, Y, Z)
plt.colorbar(cp)

ax.set_title('Contour Plot')
ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
plt.show()

# %% [markdown]
# Adding color bar

# %%
start, stop, n_values = -5, 5, 800
x_vals = np.linspace(start, stop, n_values)
y_vals = np.linspace(start, stop, n_values)
X, Y = np.meshgrid(x_vals, y_vals)


Z = np.sqrt(X**2 + Y**2)

cp = plt.contourf(X, Y, Z)
plt.colorbar(cp)

plt.title('Contour Plot')

plt.show()

# %% [markdown]
# ## 3D Plots

# %% [markdown]
# 3D Line Plot

# %%
npoints = 100
t = np.linspace(0,7*np.pi,npoints) # 0 to 7 PI
size = 1000.0*np.random.rand(npoints) # array with npoints values set to [0, 1000]
z = np.random.rand(npoints) # array of npoints in range [0,1]
x = t*np.cos(t)
y = t*np.sin(t)

fig = plt.figure()
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
ax.plot3D(x, y, t, 'green')

# %% [markdown]
# 3D Scatter Plot

# %%
npoints = 100
t = np.linspace(0,7*np.pi,npoints) # 0 to 7 PI
size = 1000.0*np.random.rand(npoints) # array with npoints values set to [0, 1000]
z = np.random.rand(npoints) # array of npoints in range [0,1]
x = t*np.cos(t)
y = t*np.sin(t)

fig = plt.figure()
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
ax.scatter3D(x, y, t, 'green')

# %% [markdown]
# 3D Plots with Contours

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/mpl_toolkits/mplot3d/art3d.py:304: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self._segments3d = np.asanyarray(segments)

# %% [markdown]
# ## Plots from Panda Dataframes
# * Good representation of tabular data that have headings for each column.
# * Inhomogenous column types - common with Excel, SQL table, ...
# * Can arbitray switch between index and label to access the data
# * Easy to filter data
# * Fast compared to list of lists

# %%
## Example from SW material 
import pandas as pd
#data = pd.read_csv('https://raw.githubusercontent.com/ay7n/RUCIL-PY-JUPYTER-DATA-VISUALIZATION/master/Data/gapminder_gdp_oceania.csv', index_col='country')
data = pd.read_csv('https://raw.githubusercontent.com/dmbala/python-data-viz/master/Data/gapminder_gdp_oceania.csv', index_col='country')
# Extract year from last 4 characters of each column name
# The current column names are structured as 'gdpPercap_(year)', 
# so we want to keep the (year) part only for clarity when plotting GDP vs. years
# To do this we use strip(), which removes from the string the characters stated in the argument
# This method works on strings, so we call str before strip()

years = data.columns.str.strip('gdpPercap_')
# Convert year values to integers, saving results back to dataframe
data.columns = years.astype(int)

# %% [markdown]
# * By default, DataFrame.plot plots with the rows as the X axis.
# * We can transpose the data in order to plot multiple series.

# %%
data
# Out:
#                     1952         1957         1962         1967         1972  \
# country
# Australia    10039.59564  10949.64959  12217.22686  14526.12465  16788.62948
# New Zealand  10556.57566  12247.39532  13175.67800  14463.91893  16046.03728
#
#                     1977         1982         1987         1992         1997  \
# country
# Australia    18334.19751  19477.00928  21888.88903  23424.76683  26997.93657
# New Zealand  16233.71770  17632.41040  19007.19129  18363.32494  21050.41377
#
#                     2002         2007
# country
# Australia    30687.75473  34435.36744
# New Zealand  23189.80135  25185.00911

# %%
data.T
# Out:
# country    Australia  New Zealand
# 1952     10039.59564  10556.57566
# 1957     10949.64959  12247.39532
# 1962     12217.22686  13175.67800
# 1967     14526.12465  14463.91893
# 1972     16788.62948  16046.03728
# 1977     18334.19751  16233.71770
# 1982     19477.00928  17632.41040
# 1987     21888.88903  19007.19129
# 1992     23424.76683  18363.32494
# 1997     26997.93657  21050.41377
# 2002     30687.75473  23189.80135
# 2007     34435.36744  25185.00911

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %% [markdown]
# ## Why other libraries - Seaborn, Plotly, Bokeh, ...
# * Pandas dataframe. The plot method on Series and DataFrame is just a simple wrapper around plt.plot
# * Data exploration
# * Interactive graphs
# * Dashboards

# %% [markdown]
# References and Further Readings
#
# * https://matplotlib.org/
# * https://www.geeksforgeeks.org/data-visualization-with-python/
# * https://www.kaggle.com/code/sanikamal/data-visualization-using-matplotlib/notebook
# * https://www.oreilly.com/library/view/python-data-science/9781491912126/ch04.html
# * https://swcarpentry.github.io/python-novice-gapminder/
# * https://realpython.com/python-matplotlib-guide/
# * https://github.com/dmbala/python-data-viz
